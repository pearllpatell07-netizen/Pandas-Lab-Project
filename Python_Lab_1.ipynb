# %%
#import Pandas and assign an abbreviated identifier "pd"
import pandas as pd
data = pd.read_csv("products.csv")
data
# Out:
#     ProductID  SupplierID                     ProductName      ContainerType  \
# 0           1           1          Almonds Hickory Smoked          Paper Bag
# 1           2           1      Almonds Roasted and Salted        Plastic Bag
# 2           3           1                    Banana Chips     Flexible Pouch
# 3           4           1                    Berry Cherry        Plastic Bag
# 4           5           1  California Original Pistachios  Plastic Container
# ..        ...         ...                             ...                ...
# 65         66           9            All-Purpose Marinade  Plastic Container
# 66         67          10                  Light Marinade     Flexible Pouch
# 67         68          10                  Mushroom Rolls          Paper Box
# 68         69          10                     Green Sauce          Paper Bag
# 69         70          10                 Fried Jalapenos        Plastic Bag
#
# ...

# %%
import pandas as pd
data = pd.read_csv("products.csv", usecols=['ProductName', 'ProductWeight', 'ProductPrice'])
data
# Out:
#                        ProductName ProductWeight  ProductPrice
# 0           Almonds Hickory Smoked          6 oz            35
# 1       Almonds Roasted and Salted          7 oz            22
# 2                     Banana Chips         14 oz            27
# 3                     Berry Cherry         10 oz            30
# 4   California Original Pistachios          2 lb            29
# ..                             ...           ...           ...
# 65            All-Purpose Marinade          8 oz            29
# 66                  Light Marinade          6 oz            39
# 67                  Mushroom Rolls         11 oz            48
# 68                     Green Sauce          8 oz            35
# 69                 Fried Jalapenos          7 oz            15
#
# [70 rows x 3 columns]

# %%
import pandas as pd
data = pd.read_csv("products.csv", usecols=[3, 4, 5])
data
# Out:
#         ContainerType ProductWeight IngredientType
# 0           Paper Bag          6 oz       GMO-Free
# 1         Plastic Bag          7 oz        Organic
# 2      Flexible Pouch         14 oz       GMO-Free
# 3         Plastic Bag         10 oz       GMO-Free
# 4   Plastic Container          2 lb       GMO-Free
# ..                ...           ...            ...
# 65  Plastic Container          8 oz        Organic
# 66     Flexible Pouch          6 oz    All-Natural
# 67          Paper Box         11 oz    All-Natural
# 68          Paper Bag          8 oz        Organic
# 69        Plastic Bag          7 oz       GMO-Free
#
# [70 rows x 3 columns]

# %%
import pandas as pd
data = pd.read_csv("products.csv", usecols=lambda col: 'Product' in col)
data
# Out:
#     ProductID                     ProductName ProductWeight  ProductPrice  \
# 0           1          Almonds Hickory Smoked          6 oz            35
# 1           2      Almonds Roasted and Salted          7 oz            22
# 2           3                    Banana Chips         14 oz            27
# 3           4                    Berry Cherry         10 oz            30
# 4           5  California Original Pistachios          2 lb            29
# ..        ...                             ...           ...           ...
# 65         66            All-Purpose Marinade          8 oz            29
# 66         67                  Light Marinade          6 oz            39
# 67         68                  Mushroom Rolls         11 oz            48
# 68         69                     Green Sauce          8 oz            35
# 69         70                 Fried Jalapenos          7 oz            15
#
#     ProductCost
# 0         11.62
# 1          7.30
# 2          8.96
# ...

# %%
import pandas as pd
data = pd.read_csv("products.csv" )
data.loc[data['ContainerType'] == 'Paper Bag']
# Out:
#     ProductID  SupplierID                     ProductName ContainerType  \
# 0           1           1          Almonds Hickory Smoked     Paper Bag
# 5           6           1                 Choice Apricots     Paper Bag
# 8           9           1               Fresh Cranberries     Paper Bag
# 9          10           1             Raw Sunflower Seeds     Paper Bag
# 12         13           2          Chocolate  Raspberries     Paper Bag
# 13         14           2                 Chocolate Fudge     Paper Bag
# 22         23           3        Roasted & Salted Cashews     Paper Bag
# 29         30           4     Traditional Swedish Cookies     Paper Bag
# 31         32           4     Peanut Butter Creme Cookies     Paper Bag
# 38         39           5                  Pizza croutons     Paper Bag
# 43         44           6                  Honey Biscuits     Paper Bag
# 50         51           7  Coconut Chocolate Chip Cookies     Paper Bag
# ...

# %%
import pandas as pd
data = pd.read_csv("products.csv")
data.iloc [:, 3] # select all values in the fourth column of the dataset
# Out:
# 0             Paper Bag
# 1           Plastic Bag
# 2        Flexible Pouch
# 3           Plastic Bag
# 4     Plastic Container
#             ...
# 65    Plastic Container
# 66       Flexible Pouch
# 67            Paper Box
# 68            Paper Bag
# 69          Plastic Bag
# Name: ContainerType, Length: 70, dtype: object

# %%
import pandas as pd
data = pd.read_csv("products.csv")
data.iloc [10,: ] # select all values in the tenth row of the dataset, excluding the headings row.
# Out:
# ProductID                               11
# SupplierID                               2
# ProductName             Cappuccino Almonds
# ContainerType            Plastic Container
# ProductWeight                         8 oz
# IngredientType                 All-Natural
# QualityRating                    Very Good
# SKU                             PDKLS-2347
# QuantityPerUnit                         30
# ProductPrice                            35
# ProductCost                          11.62
# UnitsInStock                            32
# UnitsOnOrder                             0
# ReorderLevel                            30
# CatalogLastUpdated             Apr 18 2021
# DateEnteredInventory             5/21/2012
# Name: 10, dtype: object

# %%
import pandas as pd
data = pd.read_csv("products.csv")
data.iloc [10,: 4 ]
# Out:
# ProductID                        11
# SupplierID                        2
# ProductName      Cappuccino Almonds
# ContainerType     Plastic Container
# Name: 10, dtype: object

# %%
import pandas as pd
data = pd.read_csv("products.csv" )
data.describe()
# Out:
#        ProductID  SupplierID  QuantityPerUnit  ProductPrice  ProductCost  \
# count  70.000000   70.000000        70.000000     70.000000    70.000000
# mean   35.500000    4.957143        26.085714     31.457143    10.439714
# std    20.351085    2.861213         6.544702     10.119125     3.359115
# min     1.000000    1.000000        10.000000     15.000000     4.980000
# 25%    18.250000    2.000000        24.000000     24.000000     7.960000
# 50%    35.500000    5.000000        28.000000     29.000000     9.620000
# 75%    52.750000    7.000000        30.000000     39.000000    12.940000
# max    70.000000   10.000000        35.000000     50.000000    16.600000
#
#        UnitsInStock  UnitsOnOrder  ReorderLevel
# count     70.000000      70.00000     70.000000
# mean      32.857143       4.50000     30.857143
# std        9.716691       6.97563      7.069604
# min       12.000000       0.00000     20.000000
# 25%       25.000000       0.00000     25.000000
# ...

# %%
import pandas as pd
data = pd.read_csv("products.csv")
data.sort_values(by='QualityRating')
# Out:
#     ProductID  SupplierID                ProductName      ContainerType  \
# 34         35           5            Coffee biscuits     Flexible Pouch
# 28         29           4  Chocolate Truffle Cookies     Flexible Pouch
# 19         20           3            Chunky Pretzels  Plastic Container
# 43         44           6             Honey Biscuits          Paper Bag
# 15         16           2          Chocolate Almonds        Plastic Bag
# ..        ...         ...                        ...                ...
# 32         33           5    Cinnamon Flavor Cookies          Paper Box
# 30         31           4    Chocolate Chunk Cookies     Flexible Pouch
# 27         28           4          Pepper Cheese Box          Paper Box
# 53         54           8     Chocolate Chip Brownie          Paper Bag
# 69         70          10            Fried Jalapenos        Plastic Bag
#
#    ProductWeight IngredientType QualityRating        SKU  QuantityPerUnit  \
# ...

# %%
import pandas as pd
data = pd.read_csv("products.csv")
data.sort_values(by='QualityRating', ascending=False)
# Out:
#     ProductID  SupplierID                 ProductName   ContainerType  \
# 69         70          10             Fried Jalapenos     Plastic Bag
# 64         65           9            Dried Blackberry  Flexible Pouch
# 51         52           7       Vanilla Sugar Cookies     Plastic Bag
# 53         54           8      Chocolate Chip Brownie       Paper Bag
# 54         55           8             Caramel Brownie     Plastic Bag
# ..        ...         ...                         ...             ...
# 56         57           8       Raspberry brownie bar       Paper Box
# 55         56           8                   Fruit Dip  Flexible Pouch
# 49         50           7   Fudge Nut Brownie Cookies  Flexible Pouch
# 22         23           3    Roasted & Salted Cashews       Paper Bag
# 1           2           1  Almonds Roasted and Salted     Plastic Bag
#
#    ProductWeight IngredientType QualityRating          SKU  QuantityPerUnit  \
# ...

# %%
import pandas as pd
data = pd.read_csv("products.csv")
data.sort_values(by=['IngredientType', 'QualityRating'] )
# Out:
#     ProductID  SupplierID                   ProductName      ContainerType  \
# 19         20           3               Chunky Pretzels  Plastic Container
# 34         35           5               Coffee biscuits     Flexible Pouch
# 43         44           6                Honey Biscuits          Paper Bag
# 49         50           7     Fudge Nut Brownie Cookies     Flexible Pouch
# 56         57           8         Raspberry brownie bar          Paper Box
# ..        ...         ...                           ...                ...
# 11         12           2      Chocolate Covered Apples     Flexible Pouch
# 30         31           4       Chocolate Chunk Cookies     Flexible Pouch
# 33         34           5  Coconut Flavour Cream Wafers     Flexible Pouch
# 39         40           5           Biscuits with Cream        Plastic Bag
# 68         69          10                   Green Sauce          Paper Bag
#
# ...

# %%
import pandas as pd
data = pd.read_csv("products.csv")
data.sort_values(by=['IngredientType', 'QualityRating'], ascending=False )
# Out:
#     ProductID  SupplierID                   ProductName      ContainerType  \
# 11         12           2      Chocolate Covered Apples     Flexible Pouch
# 30         31           4       Chocolate Chunk Cookies     Flexible Pouch
# 33         34           5  Coconut Flavour Cream Wafers     Flexible Pouch
# 39         40           5           Biscuits with Cream        Plastic Bag
# 68         69          10                   Green Sauce          Paper Bag
# ..        ...         ...                           ...                ...
# 19         20           3               Chunky Pretzels  Plastic Container
# 34         35           5               Coffee biscuits     Flexible Pouch
# 43         44           6                Honey Biscuits          Paper Bag
# 49         50           7     Fudge Nut Brownie Cookies     Flexible Pouch
# 56         57           8         Raspberry brownie bar          Paper Box
#
# ...

# %%
import pandas as pd
data = pd.read_csv("products.csv")
data.sort_values(by=['IngredientType', 'QualityRating'], ascending =[True, False] )
# Out:
#     ProductID  SupplierID                 ProductName      ContainerType  \
# 5           6           1             Choice Apricots          Paper Bag
# 10         11           2          Cappuccino Almonds  Plastic Container
# 16         17           2     Dark Chocolate Apricots  Plastic Container
# 27         28           4           Pepper Cheese Box          Paper Box
# 32         33           5     Cinnamon Flavor Cookies          Paper Box
# ..        ...         ...                         ...                ...
# 1           2           1  Almonds Roasted and Salted        Plastic Bag
# 14         15           2       Chocolate Blueberries        Plastic Bag
# 22         23           3    Roasted & Salted Cashews          Paper Bag
# 26         27           4                  Corn Chips          Paper Box
# 55         56           8                   Fruit Dip     Flexible Pouch
#
#    ProductWeight IngredientType QualityRating          SKU  QuantityPerUnit  \
# ...

# %%
import pandas as pd
customers = pd.read_csv("Customers.csv")
filtered_customers = customers[(customers['City'] == 'New York') | (customers['City'] == 'Houston')]
filtered_customers
# Out:
#      CustomerID FirstName    LastName                Address      City State  \
# 0             1      John     Demarco         11 Lark Street  New York    NY
# 1             2      Mary     Demania         12 Madison Ave  New York    NY
# 2             3    George      Demers    23 New Scotland Ave  New York    NY
# 3             4   Phillip   Demetriou        22 Academy Road  New York    NY
# 4             5    Andrew   Demichele         14 Glandel Ave  New York    NY
# 5             6   Michael     Demizio            23 Grove Rd  New York    NY
# 6             7    Robert    Demaggio        34 Princeton Dr  New York    NY
# 7             8  Nicholas     Demaico       44 Notre Dame Dr  New York    NY
# 8             9      Paul    Demarist       89 Mercer Street  New York    NY
# 9            10   Matthew     Demaria            90 Park Ave  New York    NY
# 10           11     Jason     Delaney         92 Madison Ave  New York    NY
# ...

# %%
import pandas as pd
Products = pd.read_csv("Products.csv")
filtered_products = Products[(Products['UnitsInStock'] > 40) | (Products['UnitsOnOrder'] >
10)][['ProductName', 'UnitsInStock', 'UnitsOnOrder']]
filtered_products
# Out:
#                       ProductName  UnitsInStock  UnitsOnOrder
# 3                    Berry Cherry            50             0
# 9             Raw Sunflower Seeds            12            15
# 11       Chocolate Covered Apples            42             0
# 17                Sesame Crackers            43             0
# 19                Chunky Pretzels            43             0
# 22       Roasted & Salted Cashews            22            15
# 24                 Water Crackers            44             0
# 25                    Nacho Chips            24            25
# 27              Pepper Cheese Box            45             0
# 28      Chocolate Truffle Cookies            41             0
# 29    Traditional Swedish Cookies            41             0
# 30        Chocolate Chunk Cookies            15            20
# 32        Cinnamon Flavor Cookies            41             0
# 35                 Lemon Biscuits            45             0
# ...

# %%
import pandas as pd
customers = pd.read_csv("Customers.csv")
filtered_customers = customers[(customers['State'] == 'NY') & (customers['City'] == 'Albany')]
result = filtered_customers[['LastName', 'FirstName', 'City', 'State']]
filtered_customers
# Out:
#      CustomerID FirstName LastName             Address    City State    Zip  \
# 13           14   Kenneth   Vanton    855 Hackett Blvd  Albany    NY  89890
# 34           35      Luis  Trindan    37 Greenbush Ave  Albany    NY  45357
# 138         139    Joanne  Riegert      31 Arizona Ave  Albany    NY  12189
# 149         150   Anthony   Miller  47 Darmouth Street  Albany    NY  12189
#
#     Country DateOfBirth CustomerSince MembershipType  BonusPoints
# 13      USA    4/6/2002      4/6/2021       Platinum         3290
# 34      USA    5/3/1999      5/3/2020         Silver         1871
# 138     USA    8/6/1986      8/6/2010       Platinum          775
# 149     USA    7/3/1991      7/3/2009           Gold         2414

# %%
import pandas as pd
customers = pd.read_csv("Customers.csv")
filtered_customers = customers[(customers['State'] == 'NY') & (customers['City'] == 'Albany')]
result = filtered_customers[['LastName', 'FirstName', 'City', 'State']]
filtered_customers
# Out:
#      CustomerID FirstName LastName             Address    City State    Zip  \
# 13           14   Kenneth   Vanton    855 Hackett Blvd  Albany    NY  89890
# 34           35      Luis  Trindan    37 Greenbush Ave  Albany    NY  45357
# 138         139    Joanne  Riegert      31 Arizona Ave  Albany    NY  12189
# 149         150   Anthony   Miller  47 Darmouth Street  Albany    NY  12189
#
#     Country DateOfBirth CustomerSince MembershipType  BonusPoints
# 13      USA    4/6/2002      4/6/2021       Platinum         3290
# 34      USA    5/3/1999      5/3/2020         Silver         1871
# 138     USA    8/6/1986      8/6/2010       Platinum          775
# 149     USA    7/3/1991      7/3/2009           Gold         2414

# %%
import pandas as pd
data = pd.read_csv("customers.csv")
data.iloc [:, 3] # select all values in the fourth column of the dataset
# Out:
# 0           11 Lark Street
# 1           12 Madison Ave
# 2      23 New Scotland Ave
# 3          22 Academy Road
# 4           14 Glandel Ave
#               ...
# 196         19 Paul Street
# 197            25 Penn Ave
# 198        98 Harbison Ave
# 199         110 Brick Road
# 200     28 Colorado Avenue
# Name: Address, Length: 201, dtype: object

# %%
customers.loc[40, ['City', 'Zip', 'DateOfBirth', 'MembershipType']]
# Out:
# City              Philadelphia
# Zip                      56789
# DateOfBirth          8/14/1999
# MembershipType        Platinum
# Name: 40, dtype: object

# %%
customers[['FirstName', 'LastName', 'CustomerSince', 'MembershipType', 'BonusPoints']]
# Out:
#     FirstName   LastName CustomerSince MembershipType  BonusPoints
# 0        John    Demarco     1/22/2021         Silver          543
# 1        Mary    Demania     7/17/2022           Gold         2977
# 2      George     Demers     3/11/2022       Platinum         3875
# 3     Phillip  Demetriou    10/12/2021           Gold         1337
# 4      Andrew  Demichele     9/27/2020         Silver         2274
# ..        ...        ...           ...            ...          ...
# 196     Jason      Datek     9/16/2000       Platinum         3050
# 197       Jim    Edwards      6/2/2000           Gold         2549
# 198     David     Wilson      3/9/2000         Silver         2294
# 199      John    Edwards      4/5/1999       Platinum         1884
# 200     David   McMillan     3/14/1999       Platinum         3387
#
# [201 rows x 5 columns]

# %%
customers[['FirstName', 'LastName', 'CustomerSince', 'MembershipType', 'BonusPoints']] \
.sort_values(by='CustomerSince', ascending=False)
# Out:
#     FirstName    LastName CustomerSince MembershipType  BonusPoints
# 115   William      Gibson      9/9/2013       Platinum         2461
# 175    Joanne      Strack      9/9/2005       Platinum          914
# 90    Michael     Occonor      9/8/2017           Gold         1370
# 96        Jim        Bink      9/5/2016       Platinum         1286
# 21       Mary     Simmons      9/3/2021           Gold         2560
# ..        ...         ...           ...            ...          ...
# 50      James      Horgan     1/21/2022         Silver          789
# 162    Arnold     Cormack     1/21/2008         Silver          851
# 80    Michael     Peteros     1/19/2019           Gold         3354
# 87     George     Vandyke     1/19/2018         Silver         3201
# 120    Edward  Harrington     1/18/2013         Silver         1602
#
# [201 rows x 5 columns]

# %%
customers[['FirstName', 'LastName', 'CustomerSince', 'MembershipType', 'BonusPoints']] \
.sort_values(by=['MembershipType', 'CustomerSince'], ascending=[True, False])
# Out:
#     FirstName    LastName CustomerSince MembershipType  BonusPoints
# 90    Michael     Occonor      9/8/2017           Gold         1370
# 21       Mary     Simmons      9/3/2021           Gold         2560
# 62      Luize     Roberts     9/29/2020           Gold         1216
# 123     Linda      Kniper     9/24/2012           Gold         3068
# 72       Jean       Dudek     9/21/2019           Gold         3779
# ..        ...         ...           ...            ...          ...
# 0        John     Demarco     1/22/2021         Silver          543
# 50      James      Horgan     1/21/2022         Silver          789
# 162    Arnold     Cormack     1/21/2008         Silver          851
# 87     George     Vandyke     1/19/2018         Silver         3201
# 120    Edward  Harrington     1/18/2013         Silver         1602
#
# [201 rows x 5 columns]

# %%
import pandas as pd

products = pd.read_csv("Products.csv")
products[(products['ContainerType'] == 'Paper Bag') | 
         (products['IngredientType'] == 'Organic')]
# Out:
#     ProductID  SupplierID                     ProductName      ContainerType  \
# 0           1           1          Almonds Hickory Smoked          Paper Bag
# 1           2           1      Almonds Roasted and Salted        Plastic Bag
# 5           6           1                 Choice Apricots          Paper Bag
# 8           9           1               Fresh Cranberries          Paper Bag
# 9          10           1             Raw Sunflower Seeds          Paper Bag
# 11         12           2        Chocolate Covered Apples     Flexible Pouch
# 12         13           2          Chocolate  Raspberries          Paper Bag
# 13         14           2                 Chocolate Fudge          Paper Bag
# 14         15           2           Chocolate Blueberries        Plastic Bag
# 17         18           2                 Sesame Crackers          Paper Box
# 18         19           2                    Crispy Pears          Paper Box
# ...

# %%
products[(products['ProductWeight'] == '9 oz') & (products['QualityRating'] == 'Very Good')]
# Out:
#     ProductID  SupplierID               ProductName      ContainerType  \
# 7           8           1         Dried Blueberries        Plastic Bag
# 11         12           2  Chocolate Covered Apples     Flexible Pouch
# 16         17           2   Dark Chocolate Apricots  Plastic Container
#
#    ProductWeight IngredientType QualityRating         SKU  QuantityPerUnit  \
# 7           9 oz       GMO-Free     Very Good  PDKLS-2347               10
# 11          9 oz        Organic     Very Good  PDKLS-2347               35
# 16          9 oz    All-Natural     Very Good   DKLS-4732               35
#
#     ProductPrice  ProductCost  UnitsInStock  UnitsOnOrder  ReorderLevel  \
# 7             28         9.29            28             0            30
# 11            37        12.28            42             0            40
# 16            46        15.27            38             0            25
#
#    CatalogLastUpdated DateEnteredInventory
# ...
